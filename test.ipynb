# %%
import pandas as pd
import os

data = {
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,20,25],
    'City':['New York','Los Angeles','Chicago']
}

df = pd.DataFrame(data)

# %%
new_row = {'Name':'Raj','Age':23,'City':'Tokyo'}

# %%
len(df)
# Out:
# 3

# %%
df.loc[len(df)] = new_row

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   20  Los Angeles
# 2  Charlie   25      Chicago
# 3      Raj   23        Tokyo
